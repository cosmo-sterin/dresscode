# %%
print("coucou")
# Out:
# coucou

# %% [markdown]
# # Coucou

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = range(0,200)
y = [np.sin(xx) for xx in x]
plt.plot(x,y)
plt.show()
